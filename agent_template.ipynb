# %%
import os
import pandas as pd
import PyPDF2
import re
import json
import google.generativeai as genai
import typing_extensions as typing
from docx import Document as DocxDocument

# 设置代理环境变量
os.environ['https_proxy'] = 'http://127.0.0.1:33210'
os.environ['http_proxy'] = 'http://127.0.0.1:33210'
os.environ['all_proxy'] = 'socks5://127.0.0.1:33211'

# 获取Google API Key
os.environ['GOOGLE_API_KEY'] = ''
#pdf_folder = '/Users/christinawang/Downloads/21281I1智能投顾/21281I1智能投顾'  # 替换为实际的PDF文件夹路径
#pdf_folder = '/Users/christinawang/Downloads/21281I1智能投顾/金融科技1、2班智能投顾期末作业/一班期末pdf'
pdf_folder = '/Users/christinawang/Downloads/21281I1智能投顾/金融科技1、2班智能投顾期末作业/二班期末pdf'
# 配置Gemini API
genai.configure(api_key=os.environ["GOOGLE_API_KEY"])

class Scores(typing.TypedDict):
    消息面分析: int
    宏观面分析和产业分析: int
    基本面分析: int
    市场面分析: int
    资产选择决策: int
    投资组合构建: int
    投资绩效评估: int
    回测分析: int
    参考文献与附录: int

class EvaluationResult(typing.TypedDict):
    summary: str
    scores: Scores
    total_score: int
    comments: str

# 使用 `response_schema` 生成 JSON 输出
generation_config = {
    "response_mime_type": "application/json",
    "response_schema": EvaluationResult
}

# 定义生成评估的函数
def generate_evaluation(text):
    prompt = f"""
你是国际顶尖研究生金融科技前沿课的教授。你的任务是评估学生的生成式AI个人应用报告，报告部分包括消息面、宏观面、产业分析、基本面、市场面的分析和决策，进行投资组合优化和绩效评估。根据以下评分标准对报告进行评估：
1. 数据获取、分析与决策（50分）
  - 消息面分析（10分）
  - 宏观面分析和产业分析（10分）
  - 基本面分析（15分）
  - 市场面分析（10分）
  - 资产选择决策（5分）
2. 投资组合优化与绩效评估（50分）
  - 投资组合构建（20分）
  - 投资绩效评估（10分）
  - 回测分析（10分）
  - 参考文献与附录（10分）

请提供报告的简要总结（如应用什么工具、什么提示词，完成了什么场景问题的解决，注意需要有具体的工具和场景名）、每个评分标准的得分（即使得分为0，也请明确标出），总分和报告评语（150字），并以JSON格式输出。

输出格式：
{{
    "summary": "简要总结",
    "scores": {{
        "消息面分析": 0,
        "宏观面分析和产业分析": 0,
        "基本面分析": 0,
        "市场面分析": 0,
        "资产选择决策": 0,
        "投资组合构建": 0,
        "投资绩效评估": 0,
        "回测分析": 0,
        "参考文献与附录": 0
    }},
    "total_score": 0,
    "comments": "报告评语"
}}

报告文本：
"{text}"
"""
    model = genai.GenerativeModel('gemini-1.5-flash', generation_config=generation_config)
    response = model.generate_content(prompt)
    return response.text

def extract_text_from_pdf(file_path):
    try:
        with open(file_path, 'rb') as file:
            reader = PyPDF2.PdfReader(file)
            text = ''
            for page in reader.pages:
                if page.extract_text():
                    text += page.extract_text()
        return text
    except Exception as e:
        print(f"Error extracting text from PDF file {file_path}: {e}")
        return ""

def extract_text_from_docx(file_path):
    try:
        doc = DocxDocument(file_path)
        text = []
        for paragraph in doc.paragraphs:
            text.append(paragraph.text)
        return '\n'.join(text)
    except Exception as e:
        print(f"Error extracting text from DOCX file {file_path}: {e}")
        return ""

def extract_info_from_filename(filename):
    # 正则表达式匹配学生学号（数字+可选字母+数字）和姓名（汉字），中间允许有空格
    match = re.match(r'(\d{5}[A-Z]?\d{3})[\s]?([\u4e00-\u9fa5\s]+)', filename)
    if not match:
        match = re.match(r'(\d{9})[\s]?([\u4e00-\u9fa5\s]+)', filename)
    
    report_title = filename.rsplit('.', 1)[0]  # 确保 report_title 总是被定义

    if match:
        student_id = match.group(1).strip()
        name = match.group(2).strip()
        return student_id, name, report_title
    else:
        return None, None, report_title


# 遍历文件夹中的PDF和DOCX文件
data = []
empty_files = []

for filename in os.listdir(pdf_folder):
    print(f"Found file: {filename}")  # Debugging output
    if filename.endswith('.pdf') or filename.endswith('.docx'):
        print(f"Processing file: {filename}")  # Debugging output
        file_path = os.path.join(pdf_folder, filename)
        student_id, name, report_title = extract_info_from_filename(filename)
        print(f"Extracted info - Student ID: {student_id}, Name: {name}, Report Title: {report_title}")  # Debugging output
        if report_title: #student_id and name
            if filename.endswith('.pdf'):
                text = extract_text_from_pdf(file_path)
            elif filename.endswith('.docx'):
                print(f"Extracting text from DOCX file: {filename}")  # Debugging output
                text = extract_text_from_docx(file_path)
            print(f"Extracted text: {text[:100]}...")  # Print first 100 characters of text for debugging
            if not text or len(text.strip()) == 0:
                empty_files.append(filename)
            elif len(text) < 100:
                empty_files.append(filename)
            else:
                try:
                    evaluation = generate_evaluation(text)
                    print("Evaluation Output:", evaluation)  # Debugging output

                    evaluation_json = json.loads(evaluation)
                    # 添加学号、姓名和报告名称
                    evaluation_json.update({"学号": student_id, "姓名": name, "报告名称": report_title})
                    data.append(evaluation_json)
                except Exception as e:
                    print(f"Error processing evaluation for {filename}: {e}")
                    print("Full Evaluation Output for Debugging:", evaluation)  # Additional debugging output

# 将结果保存到Excel文件中
if data:
    df = pd.json_normalize(data)
    df.to_excel('summary_report.xlsx', index=False)
    print("摘要已成功生成并保存到 summary_report.xlsx")

# 将空文件保存到单独的Excel文件中
if empty_files:
    empty_df = pd.DataFrame(empty_files, columns=["filename"])
    empty_df.to_excel('empty_files.xlsx', index=False)
    print("空文件列表已保存到 empty_files.xlsx")
else:
    print("未生成任何评估结果。")
# Out:
# Found file: 21158B216 +陈桂纯.pdf
# Processing file: 21158B216 +陈桂纯.pdf
# Extracted info - Student ID: 21158B216, Name: , Report Title: 21158B216 +陈桂纯
# Extracted text: 智能投顾实验
# 期末实验报告
# 报告名称： 平安银行股票分析报告 。
# 院别： 国家金融学学院 。
# 专业： 金融科技 。
# 姓名： 陈桂纯 。
# 学号： 21158B216 。
# 提交时间： 2024.06.25...
# Error processing evaluation for 21158B216 +陈桂纯.pdf: 'utf-8' codec can't encode character '\ud835' in position 8504: surrogates not allowed
# Full Evaluation Output for Debugging: {"summary": "本报告使用慧博AI研报机器人、秘塔AI、同花顺问财等生成式AI工具，以及Python编程语言，对2024年科技板块ETF进行了系统化的分析和投资决策。报告涵盖了消息面、宏观面、产业分析、基本面和市场面的分析，并构建了投资组合并进行了绩效评估和回测分析。此外，还使用Coze平台设计了一个能够提供理财投资决策建议和绩效评估服务的Bot。", "scores": {"消息面分析": 5, "宏观面分析和产业分析": 5, "基本面分析": 5, "市场面分析": 5, "资产选择决策": 0, "投资组合构建": 10, "投资绩效评估": 5, "回测分析": 5, "参考文献与附录": 5}, "total_score": 45, "comments": "报告展现了学生利用生成式AI和Python进行投资分析的能力，但整体深度和逻辑性仍需加强。例如，资产选择决策部分缺乏明确的选股依据和逻辑，投资组合构建部分仅提到了夏普比率最大化，但没有展示具体参数和优化过程。投资绩效评估部分仅展示了累积收益曲线，缺乏其他关键指标的分析和比较。回测部分也仅展示了结果图，没有解释回测方法和参数设置。建议学生在未来的学习中，深入研究投资组合理论和风险管理方法，加强数据分析和逻辑推理能力，并注重报告的清晰性和条理性。"}
#
# Found file: 21158B241+李钊瀚.pdf
# Processing file: 21158B241+李钊瀚.pdf
# Extracted info - Student ID: None, Name: None, Report Title: 21158B241+李钊瀚
# Extracted text: 智能投顾实验
# 期末实验报告
# 报告名称：智慧投顾股票投资辅助机器人。
# 院别： 国家金融学学院 。
# 专业： 金融科技 。
# 姓名： 李钊瀚 。
# 学号： 21158B241 。
# 提交时间： 2024.6.25...
# Evaluation Output: {"summary": "该实验报告使用文心一言、Coze、东方财经和Python等工具，设计了一个股票投资辅助机器人，并用它来完成了一位投资者的股票投资决策和组合优化任务。机器人可以进行消息面、宏观面、产业分析、基本面和市场面的分析，并基于此进行资产选择决策，最后使用东方财富Choice金融终端进行回测。", "scores": {"消息面分析": 10, "宏观面分析和产业分析": 10, "基本面分析": 15, "市场面分析": 10, "资产选择决策": 5, "投资组合构建": 20, "投资绩效评估": 10, "回测分析": 5, "参考文献与附录": 10}, "total_score": 95, "comments": "该报告展示了学生对生成式AI在金融科技领域应用的理解和尝试，能够使用不同的工具完成任务，并展现了较为清晰的逻辑和分析思路。在数据获取和分析方面体现了学生的努力和思考，能够清晰地描述分析步骤和方法，并呈现了相应的分析结果。在投资组合构建和评估方面，学生能够运用相关理论和工具进行分析，但缺乏对投资策略的深入讨论和优化。在回测分析方面，学生选择了使用成熟的应用进行分析，但没有展示自己的代码实现，也未能进行深入的策略优化。总的来说，该报告展现了学生较好的应用能力和学习潜力，但需要进一步提升对金融科技的理论和实践理解，并加强对投资策略的深入研究和优化。"}
#
# Found file: 21158B227 林天华 .pdf
# Processing file: 21158B227 林天华 .pdf
# Extracted info - Student ID: 21158B227, Name: 林天华, Report Title: 21158B227 林天华
# Extracted text: 智能投顾实验
# 期末实验报告
# 报告名称：利用AI大模型对股票和ETF的分析研究
# 院别： 国家金融学学院
# 专业： 金融科技
# 姓名： 林天华 。
# 学号： 21158B227
# 提交时间： 2024/6/25摘...
# Evaluation Output: {"summary": "该学生使用coze大模型构建了一个AIbot，并集成在coze平台中，实现了对股票和ETF的多维度智能分析，包括消息面、宏观面、产业面、基本面和市场面的分析，并基于分析结果进行资产选择和投资决策。最后，学生基于大模型的应用构建了一组投资组合，并对其进行了绩效评估和回测分析。", "scores": {"消息面分析": 5, "宏观面分析和产业分析": 5, "基本面分析": 10, "市场面分析": 8, "资产选择决策": 2, "投资组合构建": 15, "投资绩效评估": 5, "回测分析": 10, "参考文献与附录": 5}, "total_score": 75, "comments": "该报告总体完成度较高，学生能够利用coze大模型完成股票和ETF的多维度分析，并构建投资组合进行绩效评估。但报告在消息面、宏观面、产业分析、市场面分析以及资产选择决策方面分析不够深入，对数据结果的解释也不够充分。此外，报告的结构不够清晰，信息组织混乱，建议学生加强对报告结构和写作的训练。"}
#
# Found file: 21158B219杨铭.pdf
# Processing file: 21158B219杨铭.pdf
# Extracted info - Student ID: 21158B219, Name: 杨铭, Report Title: 21158B219杨铭
# Extracted text: 智能投顾实验
# 期末实验报告
# 报告名称： 智慧投顾实验报告 。
# 院别： 国家金融学院 。
# 专业： 金融科技 。
# 姓名： 杨铭 。
# 学号： 21158B219 。
# 提交时间： 2024年6月25日 。摘要...
# Evaluation Output: {"summary": "该报告应用了生成式AI工具对晶方科技（股票代码：603005）进行了消息面、宏观面、产业分析、基本面、市场面的分析和决策，并进行了投资组合优化和绩效评估。报告中使用了Python代码进行均值方差优化、绩效评估和回测分析。报告以晶方科技为例，演示了如何使用生成式AI工具进行投资分析，并给出了一个具体的投资方案示例。", "scores": {"消息面分析": 10, "宏观面分析和产业分析": 5, "基本面分析": 10, "市场面分析": 10, "资产选择决策": 3, "投资组合构建": 15, "投资绩效评估": 5, "回测分析": 10, "参考文献与附录": 2}, "total_score": 70, "comments": "该报告内容完整，结构清晰，对晶方科技的分析较为深入，但也存在一些不足。例如，宏观面分析和产业分析部分内容过于笼统，缺乏针对性；资产选择决策部分过于简单，没有充分利用生成式AI工具的优势；投资组合构建部分缺少对风险偏好和投资目标的明确设定；投资绩效评估部分仅仅计算了年化收益率、波动性和夏普比率等指标，缺少对其他重要指标的分析。总体而言，该报告展示了学生对生成式AI工具在金融科技领域应用的初步理解，但仍需进一步提升分析深度和应用技巧。"}
#
# Found file: 21158B225 刘棋.pdf
# Processing file: 21158B225 刘棋.pdf
# Extracted info - Student ID: 21158B225, Name: 刘棋, Report Title: 21158B225 刘棋
# Extracted text: 智能投顾实验
# 期末实验报告
# 报告名称：中证500指数智能投顾报告。
# 院别： 国家金融学学院 。
# 专业： 金融科技 。
# 姓名： 刘棋 。
# 学号： 21158B225 。
# 提交时间： 2024.6.25 ...
# Evaluation Output: {"summary": "该报告应用了COZE、同花顺问财、Python等工具，对中证500指数进行了消息面分析、宏观面分析、产业分析、基本面分析、市场面分析。并运用qstock获取数据，以及pypfopt中的函数等方式结合Python代码构建投资组合及其投资绩效评估。报告旨在探讨智能投顾技术在提升投资效率和降低投资成本方面的潜力。", "scores": {"消息面分析": 10, "宏观面分析和产业分析": 10, "基本面分析": 15, "市场面分析": 10, "资产选择决策": 5, "投资组合构建": 20, "投资绩效评估": 10, "回测分析": 10, "参考文献与附录": 0}, "total_score": 90, "comments": "该报告对中证500指数进行了全面分析，应用了多种数据分析技术，并构建了投资组合并进行了绩效评估。报告内容较为完整，但缺乏参考文献和附录，建议补充相关信息。"}
#
# Found file: 21158b223 谢熙喆.pdf
# Processing file: 21158b223 谢熙喆.pdf
# Extracted info - Student ID: None, Name: None, Report Title: 21158b223 谢熙喆
# Extracted text: 智能投顾实验
# 期末实验报告
# 报告名称： 智能分析在投资中的应用。
# 院别： 国家金融学学院 。
# 专业： 金融科技 。
# 姓名： 谢熙喆 。
# 学号： 21158B223 。
# 提交时间： 6月25 。摘要
# 本...
# Evaluation Output: {"summary": "该报告应用Cozebot和同花顺问财，通过简单提示词提问获取数据，分析了中国移动、伊利股份、紫金矿业三家公司的基本面、宏观环境、市场地位等，并进行投资绩效评估和回测分析。", "scores": {"消息面分析": 8, "宏观面分析和产业分析": 8, "基本面分析": 12, "市场面分析": 8, "资产选择决策": 3, "投资组合构建": 15, "投资绩效评估": 8, "回测分析": 5, "参考文献与附录": 5}, "total_score": 72, "comments": "该报告信息获取和分析较为全面，对三家公司的基本面、宏观环境、市场地位都有所涉及，并运用同花顺问财进行绩效评估和回测。但是，报告在资产选择决策、投资组合构建和回测分析方面存在不足，缺少有效的投资策略和组合构建方案。建议学生进一步学习投资组合优化理论，并改进报告中的回测分析部分。"}
#
# Found file: 21158B226 李东彬.pdf
# Processing file: 21158B226 李东彬.pdf
# Extracted info - Student ID: 21158B226, Name: 李东彬, Report Title: 21158B226 李东彬
# Extracted text: 智能投顾实验
# 期末实验报告
# 报告名称： 华为概念股分析与研究 。
# 院别： 国家金融学学院 。
# 专业： 金融科技 。
# 姓名： 李东彬 。
# 学号： 21158B226 。
# 提交时间： 2024/6/25 ...
# Evaluation Output: {"summary": "该报告运用LinkReaderPlugin收集数据并进行分析，包含消息面、宏观面、产业分析、基本面、市场面分析和投资组合优化与绩效评估等内容，目标是评估华为概念股BK0854的投资策略。报告使用PESTEL分析法、AI问答等工具进行分析，并利用回测技术模拟历史交易，评估策略的潜在表现。", "scores": {"消息面分析": 10, "宏观面分析和产业分析": 10, "基本面分析": 15, "市场面分析": 5, "资产选择决策": 0, "投资组合构建": 10, "投资绩效评估": 5, "回测分析": 10, "参考文献与附录": 5}, "total_score": 70, "comments": "该报告思路清晰，数据获取、分析与决策部分做得较好，但资产选择决策部分欠缺，投资组合构建和绩效评估部分较简单，需要进一步完善。建议补充资产选择决策的分析过程，进一步细化投资组合构建和绩效评估的内容，并结合实际情况进行更深入的分析和研究。"}
#
# Found file: 21158B205 何可心.pdf
# Processing file: 21158B205 何可心.pdf
# Extracted info - Student ID: 21158B205, Name: 何可心, Report Title: 21158B205 何可心
# Extracted text: 智能投顾实验
# 期末实验报告
# 报告名称：股票的投资决策分析
# 院别：国家金融学学院
# 专业：金融科技 。
# 姓名： 何可心 。
# 学号： 21158B205 。
# 提交时间： 2024.6.25 。摘要
# 本报告针...
# Evaluation Output: {"summary": "该报告使用Pofoliopilot、同花顺问财和Coze等工具，以特定提示词（\"你是一个高级金融分析师，专长于为特定股票生成财经新闻分析、基本面分析、市场表现分析和同行业对比分析\"）进行数据分析，并基于基本面、宏观面、市场表现等分析，构建投资组合并进行回测，最终为风险回避型投资者提供投资建议。", "scores": {"消息面分析": 0, "宏观面分析和产业分析": 5, "基本面分析": 10, "市场面分析": 5, "资产选择决策": 5, "投资组合构建": 10, "投资绩效评估": 5, "回测分析": 5, "参考文献与附录": 0}, "total_score": 50, "comments": "该报告展现了学生对生成式AI在金融领域的应用探索，但整体分析深度和数据支持不足。例如，报告缺乏对消息面的深入分析，对宏观面分析和产业分析的论述也不够具体，仅提及经济环境影响，但缺乏具体指标和分析。基本面分析仅简单列举了财务指标，缺乏对指标的解读和分析。市场面分析过于简略，缺乏对股价走势、市场情绪等方面的分析。资产选择决策缺乏量化分析，仅根据风险承受能力进行简单判断。投资组合构建和绩效评估缺乏具体的指标和方法，回测分析内容也较为粗略，没有展示具体的回测结果和分析。报告缺乏参考文献和附录，缺乏数据来源的说明和支撑。总体而言，报告仍需加强数据分析和理论支撑，提升分析深度和逻辑性。"}
#
# Found file: 21158B224李浚伟.pdf
# Processing file: 21158B224李浚伟.pdf
# Extracted info - Student ID: 21158B224, Name: 李浚伟, Report Title: 21158B224李浚伟
# Extracted text: 智能投顾实验
# 期末实验报告
# 报告名称：中证1000（000852）的智能投顾实验报告 。
# 院别： 国家金融学学院 。
# 专业： 金融科技 。
# 姓名： 李浚伟 。
# 学号： 21158B224 。
# 提交时间...
# Evaluation Output: {"summary": "该报告利用Coze机器人，结合Python代码对中证1000指数进行了智能投顾实验。报告中包含了消息面、宏观面、产业分析、基本面、市场面的分析，并进行了投资组合优化和绩效评估。报告使用了qstock库获取股票数据，pypfopt库进行投资组合优化，还利用回测分析了投资组合的绩效。", "scores": {"消息面分析": 10, "宏观面分析和产业分析": 5, "基本面分析": 10, "市场面分析": 10, "资产选择决策": 5, "投资组合构建": 15, "投资绩效评估": 5, "回测分析": 10, "参考文献与附录": 0}, "total_score": 70, "comments": "该报告内容完整，涵盖了智能投顾实验的各个环节。但报告缺乏参考文献和附录，导致部分内容的可信度和有效性无法验证。同时，报告在投资组合构建和绩效评估方面，没有进行深入的分析和解释，仅通过图片展示部分数据，缺乏有效的论证和说明。建议在后续研究中加强理论依据的支撑，并提供更详细的分析结果和解释，以提高报告的质量和可读性。"}
#
# Found file: 21158B234 李炯乐.pdf
# Processing file: 21158B234 李炯乐.pdf
# Extracted info - Student ID: 21158B234, Name: 李炯乐, Report Title: 21158B234 李炯乐
# Extracted text: 第1页共25页智能投顾实验
# 期末实验报告
# 报告名称： 智能投资顾问实验 。
# 院别： 国家金融学学院 。
# 专业： 金融科技 。
# 姓名： 李炯乐 。
# 学号： 21158B234 。
# 提交时间： 2024年...
# Evaluation Output: {"summary": "该学生报告利用了Coze机器人、Python编程语言、qstock等工具进行沪深300指数成分股分析，并构建了投资组合，最后进行了回测分析。", "scores": {"消息面分析": 10, "宏观面分析和产业分析": 10, "基本面分析": 15, "市场面分析": 10, "资产选择决策": 5, "投资组合构建": 20, "投资绩效评估": 10, "回测分析": 10, "参考文献与附录": 10}, "total_score": 90, "comments": "该报告整体结构清晰，内容完整，运用生成式AI工具进行了信息获取和分析，但对一些分析结果的解读和分析不够深入，需要进一步完善。在投资组合构建方面，利用PyPortfolioOpt库进行优化，并通过回测分析验证策略有效性，体现了较为专业的分析水平。"}
#
# Found file: 21158B206 李佩珊.pdf
# Processing file: 21158B206 李佩珊.pdf
# Extracted info - Student ID: 21158B206, Name: 李佩珊, Report Title: 21158B206 李佩珊
# Extracted text: 智能投顾实验
# 期末实验报告
# 报告名称：基于kimi论美的集团股票投资组合分析。
# 院别： 国家金融学学院 。
# 专业： 金融科技 。
# 姓名： 李佩珊 。
# 学号： 21158B206 。
# 提交时间： 202...
# Evaluation Output: {"summary": "该报告使用ChatGPT模型作为智能投顾工具，通过一系列提示词，对美的集团股票进行消息面、宏观面、产业、基本面、市场面分析，并构建了投资组合，进行了绩效评估和回测分析，最后给出了不同风险承受能力投资者的投资建议。", "scores": {"消息面分析": 8, "宏观面分析和产业分析": 8, "基本面分析": 12, "市场面分析": 8, "资产选择决策": 4, "投资组合构建": 15, "投资绩效评估": 8, "回测分析": 10, "参考文献与附录": 5}, "total_score": 80, "comments": "该报告总体结构清晰，信息完整，内容较为充实，但缺乏深度和个性化分析。学生在数据获取与分析方面较为熟练，能够运用ChatGPT进行信息提取和整理，但对数据的解释和解读不够深入。在投资组合构建方面，学生能运用简单的资产配置策略，但缺乏对个股的深入研究和风险评估。在投资绩效评估和回测分析方面，学生仅进行简单的指标计算，缺乏对结果的深入分析和解释。建议学生深入研究相关理论知识，加强对数据的分析和解读，提升对市场和行业的理解，并尝试使用更复杂的投资组合构建和绩效评估方法。"}
#
# Found file: 21158B245徐秋丰.pdf
# Processing file: 21158B245徐秋丰.pdf
# Extracted info - Student ID: 21158B245, Name: 徐秋丰, Report Title: 21158B245徐秋丰
# Extracted text: 智能投顾实验
# 期末实验报告
# 报告名称：基于半导体板块分散投资的双均线模型的研究。
# 院别： 国家金融学学院 。
# 专业： 金融科技 。
# 姓名： 徐秋丰 。
# 学号： 21158B245 。
# 提交时间： 20...
# Evaluation Output: {"summary": "该学生应用了Kimi、星火大模型和问财AI等生成式AI工具，以及Python编程，构建了基于双均线模型的量化交易策略，对长电科技、通富微电和晶方科技三家国内半导体领域龙头企业进行了投资组合构建和绩效评估。", "scores": {"消息面分析": 10, "宏观面分析和产业分析": 10, "基本面分析": 15, "市场面分析": 10, "资产选择决策": 5, "投资组合构建": 20, "投资绩效评估": 10, "回测分析": 10, "参考文献与附录": 10}, "total_score": 90, "comments": "该报告内容较为完整，涵盖了消息面、宏观面、产业分析、基本面和市场面分析，并基于双均线模型构建了投资组合。报告还进行了回测分析，并对投资策略的优势进行了阐述。但报告在数据获取和分析决策方面，缺乏对数据来源的详细说明，以及对数据分析结果的深入解读。另外，报告在投资组合构建方面，仅使用了三等分投资策略，没有进行更深入的优化。总的来说，该报告是一个不错的开始，但仍需进一步完善和提升。"}
#
# Found file: 21158B238+韦栋腾.pdf
# Processing file: 21158B238+韦栋腾.pdf
# Extracted info - Student ID: None, Name: None, Report Title: 21158B238+韦栋腾
# Extracted text: 智能投顾实验
# 期末实验报告
# 报告名称：运用python代码构建投资组合—基于中国A股市场实现。
# 院别： 国家金融学学院 。
# 专业： 金融科技 。
# 姓名： 韦栋腾 。
# 学号： 21158B238 。
# 提...
# Evaluation Output: {"summary": "该报告利用baostockAPI获取股票历史数据和财务数据，使用qstock获取股票新闻数据，并结合SnowNLP进行情感分析，运用pandas和numpy进行数据处理，最终构建了一个基于中国A股市场电子行业子集的智能投资顾问系统。该系统通过消息面、基本面、市场面、宏观和产业分析，对股票进行评分，并基于评分结果进行投资决策，最终构建投资组合并进行绩效评估和回测分析。", "scores": {"消息面分析": 10, "宏观面分析和产业分析": 5, "基本面分析": 10, "市场面分析": 10, "资产选择决策": 5, "投资组合构建": 15, "投资绩效评估": 10, "回测分析": 10, "参考文献与附录": 10}, "total_score": 85, "comments": "该报告展示了学生在运用生成式AI进行金融科技应用方面的努力，代码逻辑清晰，分析流程完整，但宏观和产业分析部分较为简单，缺乏对具体宏观数据和产业数据分析的深度解释。此外，投资组合构建部分可以进一步优化，例如考虑引入风险管理策略和更复杂的资金分配机制。总的来说，这份报告展现了学生在金融科技领域应用生成式AI进行投资组合管理的能力，但仍需进一步完善和深化。」"}
#
# Found file: 21158B208 谢燕霞.pdf
# Processing file: 21158B208 谢燕霞.pdf
# Extracted info - Student ID: 21158B208, Name: 谢燕霞, Report Title: 21158B208 谢燕霞
# Extracted text: 智能投顾实验
# 期末实验报告
# 报告名称： 投资组合优化 。
# 院别： 国家金融学学院 。
# 专业： 金融科技 。
# 姓名： 谢燕霞 。
# 学号： 21158B208 。
# 提交时间： 2024年6月25日 。摘要...
# Evaluation Output: {"summary": "该报告使用Coze、Kimi等生成式AI工具，结合Python技术，分析了科技板块ETF的市场表现，并对股票代码300122和600196进行了回测分析。", "scores": {"消息面分析": 5, "宏观面分析和产业分析": 5, "基本面分析": 10, "市场面分析": 5, "资产选择决策": 5, "投资组合构建": 15, "投资绩效评估": 10, "回测分析": 15, "参考文献与附录": 0}, "total_score": 75, "comments": "该报告利用生成式AI和Python技术，对科技板块ETF进行了深入分析，包括消息面、宏观面、产业、基本面和市场面。报告对股票代码300122和600196进行了回测分析，并对投资策略进行了有效性验证。但报告缺乏参考文献和附录，对一些关键分析数据的来源没有明确说明，这会影响报告的可靠性和可信度。"}
#
# Found file: 21158B212 梁颖诗.pdf
# Processing file: 21158B212 梁颖诗.pdf
# Extracted info - Student ID: 21158B212, Name: 梁颖诗, Report Title: 21158B212 梁颖诗
# Extracted text: 智能投顾实验
# 期末实验报告
# 报告名称：基于智能投顾平台的数据获取、分析与投资组合
# 优化研究
# 院别： 国家金融学学院 。
# 专业： 金融科技 。
# 姓名： 梁颖诗 。
# 学号： 21158B212 。
# 提交时...
# Evaluation Output: {"summary": "该报告使用Coze生成式AI聊天机器人和PortfolioPilot投资组合管理平台。学生创建名为“金融分析师”的AI机器人，利用联网插件和知识库进行消息面、宏观面、产业分析、基本面和市场面的分析，并给出投资建议。最后使用PortfolioPilot构建投资组合，并进行绩效评估和回测分析。", "scores": {"消息面分析": 10, "宏观面分析和产业分析": 10, "基本面分析": 15, "市场面分析": 10, "资产选择决策": 5, "投资组合构建": 20, "投资绩效评估": 10, "回测分析": 10, "参考文献与附录": 10}, "total_score": 100, "comments": "该报告结构清晰，内容完整，体现了学生对生成式AI和投资组合管理的理解和应用能力。学生利用Coze和PortfolioPilot两个工具进行数据分析和投资组合优化，并提供了详细的步骤和结果展示。报告中包含了合理的分析逻辑、清晰的图表和数据展示，以及对投资决策和风险管理的分析，展现了较强的专业能力。"}
#
# Found file: 21158B220岳铠骏.pdf
# Processing file: 21158B220岳铠骏.pdf
# Extracted info - Student ID: 21158B220, Name: 岳铠骏, Report Title: 21158B220岳铠骏
# Extracted text: 智能投顾实验
# 期末实验报告
# 报告名称： 关于智能投顾模型报告 。
# 院别： 国际金融学学院 。
# 专业： 金融科技 。
# 姓名： 岳铠骏 。
# 学号： 21158B220 。
# 提交时间： 2024/6/24 ...
# Evaluation Output: {"summary": "该报告利用了数据驱动、目标导向、分步实施、实时交互、模拟操作等方法，训练了名为Kimi和Coze的AI助手，并使用东方财富网和数据宝的数据资源进行分析。报告以腾讯控股（00700）和网易-S（09999）为分析对象，进行消息面、宏观面、产业分析、基本面、市场面分析，并构建了投资组合并进行回测分析。", "scores": {"消息面分析": 5, "宏观面分析和产业分析": 5, "基本面分析": 0, "市场面分析": 0, "资产选择决策": 0, "投资组合构建": 0, "投资绩效评估": 0, "回测分析": 0, "参考文献与附录": 5}, "total_score": 20, "comments": "报告对AI的训练方法和工具进行了详细介绍，并展示了部分分析结果。但缺乏基本面、市场面分析和投资组合构建、评估、回测等关键内容，以及具体的数据和分析过程。建议补充相关内容，并提供更详细的分析结果和数据支持。"}
#
# Found file: 21158B248 张军豪 .pdf
# Processing file: 21158B248 张军豪 .pdf
# Extracted info - Student ID: 21158B248, Name: 张军豪, Report Title: 21158B248 张军豪
# Extracted text: 智能投顾实验
# 期末实验报告
# 报告名称：分析近一年中石化的市场表现
# 院别： 国家金融学学院
# 专业： 金融科技 。
# 姓名： 张军豪 。
# 学号： 21158B248
# 提交时间： 2024年6月25日摘要
# 要...
# Evaluation Output: {"summary": "该学生应用Coze、Kimi、慧博AI研报机器人，秘塔AI投索等生成式AI工具分析中石化近一年的市场表现，并利用Python构建包含中石化、美的集团、万科企业、中国平安、中通客车的投资组合，并进行绩效评估和回测分析。", "scores": {"消息面分析": 7, "宏观面分析和产业分析": 7, "基本面分析": 10, "市场面分析": 8, "资产选择决策": 8, "投资组合构建": 15, "投资绩效评估": 10, "回测分析": 5, "参考文献与附录": 0}, "total_score": 70, "comments": "该学生能够运用多种生成式AI工具和Python代码完成股票分析、投资组合构建和绩效评估，展现了较强的学习能力和实践能力。但报告整体结构不够清晰，缺乏逻辑性，例如投资组合构建部分，只是简单列出投资目标、行业分布、投资比例，缺乏对投资逻辑的阐述。此外，参考文献与附录部分较为简陋，缺少具体的代码和数据来源。建议学生在以后的报告写作中更加注重逻辑性和条理性，并完善参考文献与附录部分，以提高报告的质量。"}
#
# Found file: 21158B240+陈嘉乐.pdf
# Processing file: 21158B240+陈嘉乐.pdf
# Extracted info - Student ID: None, Name: None, Report Title: 21158B240+陈嘉乐
# Extracted text: 智能投顾实验
# 期末实验报告
# 报告名称： 智慧投资小顾问 。
# 院别： 国家金融学学院 。
# 专业： 金融科技 。
# 姓名： 陈嘉乐 。
# 学号： 21158B240 。
# 提交时间： 2024/6/25 。目录...
# Evaluation Output: {"summary": "该学生使用Coze工具，构建了两个bot来完成智能投顾任务。第一个bot用于数据获取、分析与决策，通过设定角色、提示词，分析了贵州茅台等股票的消息面、宏观面、产业分析、基本面、市场面，并给出资产选择决策建议。第二个bot用于投资组合优化与绩效评估，基于用户提供的股票池，根据用户的风险偏好、投资目标和投资期限等，构建了投资组合，并进行了投资组合绩效评估、回测分析和优化建议。在回测分析部分，学生还使用Python代码对贵州茅台进行了布林线策略回测，并展示了回测结果。", "scores": {"消息面分析": 10, "宏观面分析和产业分析": 10, "基本面分析": 15, "市场面分析": 10, "资产选择决策": 5, "投资组合构建": 20, "投资绩效评估": 10, "回测分析": 10, "参考文献与附录": 10}, "total_score": 90, "comments": "该报告结构完整，内容清晰，展现了学生对生成式AI在智能投顾领域的应用理解。学生能够有效利用Coze工具进行数据获取、分析和决策，并通过设定角色、提示词，引导bot完成特定任务。在投资组合优化与绩效评估部分，学生展现了较强的量化投资知识，能够进行布林线策略回测，并对回测结果进行分析。总体而言，该报告体现了学生对金融科技前沿课知识的掌握和应用能力，值得肯定。"}
#
# Found file: 21158B217朱沛盈.pdf
# Processing file: 21158B217朱沛盈.pdf
# Extracted info - Student ID: 21158B217, Name: 朱沛盈, Report Title: 21158B217朱沛盈
# Extracted text: 智能投顾实验
# 期末实验报告
# 报告名称： 智能投顾实验 。
# 院别： 国家金融学院 。
# 专业： 金融科技 。
# 姓名： 朱沛盈 。
# 学号： 21158B217 。
# 提交时间： 2024.6.25 。摘要
# 部...
# Evaluation Output: {"summary": "该报告使用Coze、ChatGPT、Python和Portfoliopilot网站等工具，分析了特斯拉公司的消息面、宏观面、产业面、基本面和市场面，并构建了包含金融服务、能源、零售、科技等多个行业的投资组合，最后进行了回测分析。", "scores": {"消息面分析": 5, "宏观面分析和产业分析": 5, "基本面分析": 10, "市场面分析": 5, "资产选择决策": 3, "投资组合构建": 10, "投资绩效评估": 10, "回测分析": 10, "参考文献与附录": 5}, "total_score": 63, "comments": "该报告尝试运用生成式AI工具进行金融数据分析和投资决策，展现了学生对金融科技的初步理解和应用能力。但是，报告内容缺乏深度，分析方法较为简单，缺乏对金融分析的专业性和严谨性。例如，在消息面和宏观面分析中，仅简单使用Coze获取信息，未进行深入分析和解读。在基本面分析中，仅使用了Python进行简单的财务指标计算，缺乏对财务指标的深入分析和解释。在投资组合构建中，仅简单根据行业分布进行选择，未考虑投资组合的风险收益特征和资产配置策略。此外，回测分析仅针对几个特殊时期进行，缺乏对不同市场环境下投资组合表现的全面评估。总体而言，该报告展示了学生对金融科技的学习和应用，但缺乏专业性和深度，还需要进一步学习和实践。"}
#
# Found file: 21158B242张嘉乐.pdf
# Processing file: 21158B242张嘉乐.pdf
# Extracted info - Student ID: 21158B242, Name: 张嘉乐, Report Title: 21158B242张嘉乐
# Extracted text: 智能投顾实验
# 期末实验报告
# 报告名称： 智能投顾机器人训练分析 。
# 院别： 国家金融学院 。
# 专业： 金融科技 。
# 姓名： 张嘉乐 。
# 学号： 21158B242 。
# 提交时间： 2024.6.25 ...
# Evaluation Output: {"summary": "本报告利用Coze、Kimi、慧博AT研报机器人等生成式AI工具，以及秘塔AI搜索等高效搜索引擎，结合JupyterNotebook、pandas、numpy等数据处理库，对科技板块ETF（假设为ETE）进行了全面的市场分析，探讨了投资组合优化策略，并对投资组合绩效进行了评估。", "scores": {"消息面分析": 10, "宏观面分析和产业分析": 10, "基本面分析": 15, "市场面分析": 10, "资产选择决策": 5, "投资组合构建": 20, "投资绩效评估": 10, "回测分析": 10, "参考文献与附录": 0}, "total_score": 90, "comments": "该报告利用多种生成式AI工具和数据处理库对科技板块ETF进行了全面的分析，展示了对消息面、宏观面、基本面、市场面等维度的理解，并进行了合理的投资组合构建和绩效评估，但缺乏参考文献和附录，建议补充相关内容，以增强报告的可靠性和可信度。"}
#
# Found file: 21158B247 黄健成.pdf
# Processing file: 21158B247 黄健成.pdf
# Extracted info - Student ID: 21158B247, Name: 黄健成, Report Title: 21158B247 黄健成
# Extracted text: 第1页共28页智能投顾实验
# 期末实验报告
# 报告名称：深证200指数的智能投顾分析与投资策略研究
# 院别： 国家金融学学院 。
# 专业： 金融科技 。
# 姓名： 黄健成 。
# 学号： 21158B247 。
# 提...
# Evaluation Output: {"summary": "学生利用Coze机器人，通过设计提示词，获取深证200指数的消息面、宏观面、产业分析、基本面和市场面的信息，并选择兴齐眼药、中航电测、杰瑞股份、伟星新材和东山精密五支股票构建投资组合。", "scores": {"消息面分析": 10, "宏观面分析和产业分析": 10, "基本面分析": 10, "市场面分析": 10, "资产选择决策": 5, "投资组合构建": 15, "投资绩效评估": 10, "回测分析": 0, "参考文献与附录": 0}, "total_score": 70, "comments": "该报告展现了学生利用生成式AI进行金融科技分析的能力，能够利用工具获取和分析信息，并进行投资组合的构建和评估。但报告缺乏回测分析和参考文献，建议补充完善。"}
#
# Found file: 21158B250 关博文.pdf
# Processing file: 21158B250 关博文.pdf
# Extracted info - Student ID: 21158B250, Name: 关博文, Report Title: 21158B250 关博文
# Extracted text: 智能投顾实验
# 期末实验报告
# 报告名称：新能源汽车行业投资分析与该行业组合绩效评估报告
# 院别：国家金融学学院 。
# 专业：金融科技 。
# 姓名：关博文 。
# 学号：21158B250 。
# 提交时间：2024年...
# Evaluation Output: {"summary": "该报告利用了kimi和星火大模型对新能源汽车行业进行消息面、宏观面、产业面、基本面和市场面的分析，并选择比亚迪和长安汽车构建投资组合，最后使用Python代码进行回测分析。", "scores": {"消息面分析": 5, "宏观面分析和产业分析": 7, "基本面分析": 10, "市场面分析": 5, "资产选择决策": 3, "投资组合构建": 10, "投资绩效评估": 5, "回测分析": 10, "参考文献与附录": 5}, "total_score": 60, "comments": "该报告展示了学生对生成式AI工具的应用能力，能够借助工具进行数据获取和分析，但分析深度和逻辑性有待提升。投资组合构建部分较为简单，缺乏对风险控制的考虑，回测分析代码逻辑较为清晰，但缺乏对结果的深入解释。总体而言，报告内容基本完整，但需要进一步加强分析深度和逻辑性，提升报告的专业性和说服力。"}
#
# Found file: 21158B222 曾宇.pdf
# Processing file: 21158B222 曾宇.pdf
# Extracted info - Student ID: 21158B222, Name: 曾宇, Report Title: 21158B222 曾宇
# Extracted text: 第1页共35页智能投顾实验
# 期末实验报告
# 报告名称：中证100指数的智能投顾分析与投资策略研究。
# 院别： 国家金融学学院 。
# 专业： 金融科技 。
# 姓名： 曾宇 。
# 学号： 21158B222 。
# 提...
# Evaluation Output: {"summary": "学生使用Coze机器人进行智能投顾实验，利用预设的提示词完成对中证100指数的消息面、宏观面、产业分析、基本面和市场面的分析，并根据分析结果选择5只股票（中远海控、中国移动、中兴通讯、海康威视、长江电力）构建投资组合，最后使用Python代码进行投资组合回测分析。", "scores": {"消息面分析": 5, "宏观面分析和产业分析": 8, "基本面分析": 10, "市场面分析": 7, "资产选择决策": 3, "投资组合构建": 15, "投资绩效评估": 10, "回测分析": 10, "参考文献与附录": 2}, "total_score": 70, "comments": "学生能运用智能投顾工具进行股票市场分析，并利用Python代码构建投资组合和进行回测分析，体现了其在金融科技方面的学习能力。但报告在资产选择决策和参考文献方面略显不足。建议学生进一步学习资产选择策略和金融科技相关研究，提升报告的深度和完整性。"}
#
# Found file: 21158B249 吴泽楷.pdf
# Processing file: 21158B249 吴泽楷.pdf
# Extracted info - Student ID: 21158B249, Name: 吴泽楷, Report Title: 21158B249 吴泽楷
# Extracted text: 智能投顾实验
# 期末实验报告
# 报告名称： 上证100的智能投顾分析。
# 院别： 国家金融学院 。
# 专业： 金融科技二班 。
# 姓名： 吴泽楷 。
# 学号： 21158B249 。
# 提交时间： 2024.6.2...
# Evaluation Output: {"summary": "学生使用了Coze机器人和PyPortfolioOpt、qstock等数据库，结合Python代码对上证100指数进行了智能投顾分析，最终构建了一个以艾力斯和新天然气为主要资产的投资组合。Coze机器人提供了消息面、宏观面、产业分析、基本面、市场面的分析结果，为投资组合构建提供了依据。", "scores": {"消息面分析": 10, "宏观面分析和产业分析": 10, "基本面分析": 15, "市场面分析": 10, "资产选择决策": 5, "投资组合构建": 20, "投资绩效评估": 10, "回测分析": 10, "参考文献与附录": 0}, "total_score": 90, "comments": "该报告展现了学生对智能投顾技术的理解和应用能力。学生运用Coze机器人和Python代码进行了消息面、宏观面、产业分析、基本面、市场面的分析，并进行了投资组合优化和绩效评估。报告内容较为完整，但缺乏参考文献和附录，建议补充相关内容以提高报告的完整性和可信度。"}
#
# Found file: 21158B228 谢仕坤.pdf
# Processing file: 21158B228 谢仕坤.pdf
# Extracted info - Student ID: 21158B228, Name: 谢仕坤, Report Title: 21158B228 谢仕坤
# Extracted text: 智能投顾实验
# 期末实验报告
# 报告名称： 智能投顾之量化投资策略优化研究 。
# 院别： 国家金融学学院 。
# 专业： 金融科技 。
# 姓名： 谢仕坤 。
# 学号： 21158B228 。
# 提交时间： 2024年...
# Evaluation Output: {"summary": "该学生利用Python编程和Pandas、NumPy等库对A股市场中的股票进行了量化分析，并使用生成式AI工具Coze和Kimi收集了科技板块相关的新闻和市场情绪数据。该报告应用了夏普比率进行投资组合优化，并进行了回测分析。", "scores": {"消息面分析": 5, "宏观面分析和产业分析": 5, "基本面分析": 10, "市场面分析": 5, "资产选择决策": 5, "投资组合构建": 15, "投资绩效评估": 10, "回测分析": 10, "参考文献与附录": 5}, "total_score": 75, "comments": "该报告展示了学生对量化投资策略的理解和应用能力。学生利用Python编程和相关的库实现了投资组合优化和回测分析，并通过生成式AI工具收集了相关数据。报告中还分析了宏观经济指标和科技产业发展趋势，并对投资组合进行了绩效评估。但报告在数据获取、分析与决策方面较为简单，缺乏对消息面、宏观面、产业分析、基本面和市场面的深入分析。建议学生在未来的报告中进一步完善数据分析和模型构建，以提高报告的质量和深度。"}
#
# Found file: 21158B211庞雅文.pdf
# Processing file: 21158B211庞雅文.pdf
# Extracted info - Student ID: 21158B211, Name: 庞雅文, Report Title: 21158B211庞雅文
# Extracted text: 智能投顾实验
# 期末实验报告
# 报告名称： 优选汽车股 。
# 院别： 国家金融学学 。
# 专业： 金融科技 。
# 姓名： 庞雅文 。
# 学号： 21158B211 。
# 提交时间： 2024年6月25日 。摘要
# 本...
# Evaluation Output: {"summary": "该报告使用Coze智能投顾机器人和文心一言进行股票分析，选择五只汽车股进行分析和评分，并最终推荐比亚迪和长安汽车作为投资组合，最后使用同花顺网站进行回测。", "scores": {"消息面分析": 10, "宏观面分析和产业分析": 5, "基本面分析": 10, "市场面分析": 5, "资产选择决策": 3, "投资组合构建": 15, "投资绩效评估": 5, "回测分析": 5, "参考文献与附录": 0}, "total_score": 63, "comments": "该报告尝试使用Coze和文心一言进行新闻分析和基本面分析，但缺乏对宏观面和产业面的深入研究，且投资组合构建和回测分析也较为简单，缺乏对投资风险的评估和管理。建议学生在未来学习中更深入地理解和运用金融科技工具，并结合实际情况进行更全面的分析和研究。"}
#
# Found file: 21158B209 黎蕙欣.pdf
# Processing file: 21158B209 黎蕙欣.pdf
# Extracted info - Student ID: 21158B209, Name: 黎蕙欣, Report Title: 21158B209 黎蕙欣
# Extracted text: 智能投顾实验
# 期末实验报告
# 报告名称：对2024年国投资本股票市场表现的分析。
# 院别： 国家金融学学院 。
# 专业： 金融科技 。
# 姓名： 黎蕙欣 。
# 学号： 21158B209 。
# 提交时间： 202...
# Evaluation Output: {"summary": "该报告使用coze、秘塔AI、巨潮和Kimi等智能工具，分析了国投资本股票市场表现，并构建了一个包含国投电力股票、国投转债和国投瑞银新能源混合基金的投资组合，进行回测分析和绩效评估。", "scores": {"消息面分析": 7, "宏观面分析和产业分析": 8, "基本面分析": 10, "市场面分析": 6, "资产选择决策": 4, "投资组合构建": 15, "投资绩效评估": 10, "回测分析": 5, "参考文献与附录": 5}, "total_score": 70, "comments": "该报告展示了学生运用生成式AI工具进行金融分析的能力，对国投资本进行了较为全面的分析，构建了多元化投资组合，并进行了绩效评估和回测分析。但是，报告在资产选择决策、回测分析和参考文献等方面仍然存在一些不足，建议学生进一步完善。"}
#
# Found file: 21158B243朱森宇.pdf
# Processing file: 21158B243朱森宇.pdf
# Extracted info - Student ID: 21158B243, Name: 朱森宇, Report Title: 21158B243朱森宇
# Extracted text: 智能投顾实验
# 期末实验报告
# 报告名称： 智能股票投资平台 。
# 院别： 国家金融学学院 。
# 专业： 金融科技 。
# 姓名： 朱森宇 。
# 学号： 21158B243 。
# 提交时间： 2024.6.25 。摘...
# Evaluation Output: {"summary": "该报告使用 ChatGPT 和 Coze 工具进行智能股票投资平台的构建，并结合 Python 代码进行数据分析、投资组合构建、评估和回测。利用 ChatGPT 进行消息面、宏观面、产业分析、基本面分析、市场面分析以及资产选择决策。使用 Coze 插件获取财经新闻、财务指标和市场数据。使用 Python 代码计算投资组合的收益率、波动率、协方差矩阵等指标，并进行回测分析。", "scores": {"消息面分析": 5, "宏观面分析和产业分析": 3, "基本面分析": 5, "市场面分析": 5, "资产选择决策": 2, "投资组合构建": 15, "投资绩效评估": 10, "回测分析": 10, "参考文献与附录": 5}, "total_score": 60, "comments": "该报告尝试使用 ChatGPT 和 Coze 工具进行智能股票投资平台的构建，并结合 Python 代码进行数据分析、投资组合构建、评估和回测。在数据获取和分析方面，学生展示了一定的能力，但缺少对数据结果的深入分析和解释。在投资组合构建和评估方面，学生基本掌握了相关知识和技能，但缺少对模型参数的解释和敏感性分析。总体而言，该报告展现了学生在运用生成式 AI 工具进行金融科技研究方面的初步尝试，但还需要进一步完善和深入分析。"}
#
# Found file: 21158B207  钟思琳.pdf
# Processing file: 21158B207  钟思琳.pdf
# Extracted info - Student ID: 21158B207, Name: 钟思琳, Report Title: 21158B207  钟思琳
# Extracted text: 智能投顾实验
# 期末实验报告
# 报告名称： 中国农业银行股票分析报告。
# 院别： 国家金融学学院 。
# 专业： 金融科技 。
# 姓名： 钟思琳 。
# 学号： 21158B207 。
# 提交时间： 2024年6月25...
# Evaluation Output: {"summary": "该报告使用生成式AI分析了中国农业银行的股票，并构建了包含中国农业银行、深圳机场和TCL科技三只股票的投资组合。该报告的应用场景是基于市场消息、宏观经济、行业分析、公司基本面和市场分析来进行股票投资组合优化和绩效评估。", "scores": {"消息面分析": 8, "宏观面分析和产业分析": 9, "基本面分析": 12, "市场面分析": 8, "资产选择决策": 3, "投资组合构建": 16, "投资绩效评估": 8, "回测分析": 6, "参考文献与附录": 8}, "total_score": 80, "comments": "该报告结构完整，分析思路清晰，数据分析基本准确，展现了生成式AI在金融科技领域应用的潜力。但在资产选择决策方面，分析过于简单，缺乏对投资组合的风险分析和更深入的决策逻辑。建议学生在未来的报告中进一步强化对投资组合风险的评估，并提供更全面的决策分析，以提升报告的实用性。"}
#
# Found file: 21158B235 黄学勤.pdf
# Processing file: 21158B235 黄学勤.pdf
# Extracted info - Student ID: 21158B235, Name: 黄学勤, Report Title: 21158B235 黄学勤
# Extracted text: 智能投顾实验
# 期末实验报告
# 报告名称： 智能投顾 。
# 院别： 国家金融学学院 。
# 专业： 金融科技 。
# 姓名： 黄学勤 。
# 学号： 21158B235 。
# 提交时间： 2024.6.25 。摘要
# 本报...
# Evaluation Output: {"summary": "该学生利用生成式AI工具（Coze、kimi）和Python编程工具（qstock、聚宽）对新能源领域进行分析，构建了智能投顾策略，并进行投资组合优化和回测。生成式AI工具主要用于获取和分析数据，如筛选10只股票并制定投资组合策略，而Python工具用于进行投资组合构建和绩效评估。", "scores": {"消息面分析": 5, "宏观面分析和产业分析": 7, "基本面分析": 10, "市场面分析": 5, "资产选择决策": 5, "投资组合构建": 15, "投资绩效评估": 5, "回测分析": 5, "参考文献与附录": 5}, "total_score": 62, "comments": "该报告整体框架清晰，内容较为完整，体现了学生运用生成式AI工具和Python编程工具的能力。学生能够运用Coze和kimi等AI工具进行信息搜集和初步分析，但还需要进一步提升对数据的分析和理解。投资组合构建部分逻辑较为清晰，但最终的绩效评估结果并不理想，需要进一步改进策略和参数设置。回测部分仅展示了部分指标，需要进一步完善回测内容。建议学生加强对市场和投资策略的理解，提升分析能力和解决问题的能力。"}
#
# Found file: 21158B246  任鹏飞.pdf
# Processing file: 21158B246  任鹏飞.pdf
# Extracted info - Student ID: 21158B246, Name: 任鹏飞, Report Title: 21158B246  任鹏飞
# Extracted text: 智能投顾实验
# 期末实验报告
# 报告名称： 智能投顾实验报告 。
# 院别： 国家金融学学院 。
# 专业： 金融科技 。
# 姓名： 任鹏飞 。
# 学号： 21158B246 。
# 提交时间： 2024-6-25 。摘...
# Evaluation Output: {"summary": "该报告利用文心一言、COZE、KIMI 等 AI 生成工具，Python、Jupyter Notebook、pandas 等编程工具，以及股票和东方财富等数据库，尝试构建浙江建投和川润股份两只股票的投资组合。报告使用了 AI 生成工具进行消息面、宏观面、产业分析、基本面、市场面的分析，并根据 AI 分析结果进行资产选择决策和投资组合构建。最后使用同花顺问财进行回测和绩效分析。", "scores": {"消息面分析": 5, "宏观面分析和产业分析": 5, "基本面分析": 10, "市场面分析": 5, "资产选择决策": 2, "投资组合构建": 10, "投资绩效评估": 5, "回测分析": 5, "参考文献与附录": 0}, "total_score": 52, "comments": "该报告尝试利用 AI 工具进行投资分析，并构建投资组合进行回测，展现了对智能投顾应用的初步探索。然而，报告缺乏对 AI 工具具体使用方法的描述，以及对分析结果的深度解读。此外，报告没有提供参考文献和附录，不利于读者了解分析过程和验证结果。建议补充 AI 工具的使用细节、分析结果的解释以及参考文献和代码等内容，提升报告的完整性和可信度。"}
#
# 摘要已成功生成并保存到 summary_report.xlsx
# 未生成任何评估结果。
